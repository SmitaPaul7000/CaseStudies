# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

# %%
# word tokenization and part-of-speech tagging applied on the sentence.
def preprocess(sent):
    sent = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent

# %%
ex = 'Mark playing in garden with his friend John and searching for games on Google, on Monday at 11, suddenly they got $4 :)'

# %% [markdown]
# ### list of tuples containing the individual words in the sentence and their associated part-of-speech.

# %%
sent = preprocess(ex)
sent
# Out:
# [('Mark', 'NNP'),
#  ('playing', 'NN'),
#  ('in', 'IN'),
#  ('garden', 'NN'),
#  ('with', 'IN'),
#  ('his', 'PRP$'),
#  ('friend', 'NN'),
#  ('John', 'NNP'),
#  ('and', 'CC'),
#  ('searching', 'VBG'),
#  ('for', 'IN'),
#  ('games', 'NNS'),
#  ('on', 'IN'),
#  ('Google', 'NNP'),
#  (',', ','),
#  ('on', 'IN'),
#  ('Monday', 'NNP'),
#  ('at', 'IN'),
#  ('11', 'CD'),
#  (',', ','),
#  ('suddenly', 'RB'),
#  ('they', 'PRP'),
#  ('got', 'VBD'),
#  ('$', '$'),
#  ('4', 'CD'),
#  (':', ':'),
#  (')', ')')]

# %% [markdown]
# Now we’ll implement noun phrase chunking to identify named entities using a regular expression consisting of rules that indicate how sentences should be chunked.
# Our chunk pattern consists of one rule, that a noun phrase, NP, should be formed whenever the chunker finds an optional determiner, DT, followed by any number of adjectives, JJ, and then a noun, NN.

# %%
pattern = 'NP: {<DT>?<JJ>*<NN>}'

# %% [markdown]
# ### Chunking

# %%
cp = nltk.RegexpParser(pattern)
cs = cp.parse(sent)
print(cs)
# Out:
# (S
#   Mark/NNP
#   (NP playing/NN)
#   in/IN
#   (NP garden/NN)
#   with/IN
#   his/PRP$
#   (NP friend/NN)
#   John/NNP
#   and/CC
#   searching/VBG
#   for/IN
#   games/NNS
#   on/IN
#   Google/NNP
#   ,/,
#   on/IN
#   Monday/NNP
#   at/IN
#   11/CD
#   ,/,
#   suddenly/RB
#   they/PRP
#   got/VBD
#   $/$
#   4/CD
#   :/:
#   )/))

# %%
from nltk.chunk import conlltags2tree, tree2conlltags
from pprint import pprint
from nltk.chunk import ne_chunk
iob_tagged = tree2conlltags(cs)
pprint(iob_tagged)
# Out:
# [('Mark', 'NNP', 'O'),
#  ('playing', 'NN', 'B-NP'),
#  ('in', 'IN', 'O'),
#  ('garden', 'NN', 'B-NP'),
#  ('with', 'IN', 'O'),
#  ('his', 'PRP$', 'O'),
#  ('friend', 'NN', 'B-NP'),
#  ('John', 'NNP', 'O'),
#  ('and', 'CC', 'O'),
#  ('searching', 'VBG', 'O'),
#  ('for', 'IN', 'O'),
#  ('games', 'NNS', 'O'),
#  ('on', 'IN', 'O'),
#  ('Google', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('on', 'IN', 'O'),
#  ('Monday', 'NNP', 'O'),
#  ('at', 'IN', 'O'),
#  ('11', 'CD', 'O'),
#  (',', ',', 'O'),
#  ('suddenly', 'RB', 'O'),
#  ('they', 'PRP', 'O'),
#  ('got', 'VBD', 'O'),
#  ('$', '$', 'O'),
#  ('4', 'CD', 'O'),
#  (':', ':', 'O'),
#  (')', ')', 'O')]

# %% [markdown]
# there is one token per line, each with its part-of-speech tag and its named entity tag. Based on this training corpus, we can construct a tagger that can be used to label new sentences; and use the nltk.chunk.conlltags2tree() function to convert the tag sequences into a chunk tree.

# %%
ne_tree = ne_chunk(pos_tag(word_tokenize(ex)))
print(ne_tree)
# Out:
# (S
#   (PERSON Mark/NNP)
#   playing/NN
#   in/IN
#   garden/NN
#   with/IN
#   his/PRP$
#   friend/NN
#   (PERSON John/NNP)
#   and/CC
#   searching/VBG
#   for/IN
#   games/NNS
#   on/IN
#   (GPE Google/NNP)
#   ,/,
#   on/IN
#   Monday/NNP
#   at/IN
#   11/CD
#   ,/,
#   suddenly/RB
#   they/PRP
#   got/VBD
#   $/$
#   4/CD
#   :/:
#   )/))

# %% [markdown]
# # SpaCy
# SpaCy’s named entity recognition has been trained on the OntoNotes 5 corpus

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
doc = nlp(ex)
pprint([(X.text, X.label_) for X in doc.ents])
# Out:
# [('Mark', 'PERSON'),
#  ('John', 'PERSON'),
#  ('Google', 'ORG'),
#  ('Monday', 'DATE'),
#  ('11', 'CARDINAL'),
#  ('4', 'MONEY')]

# %% [markdown]
# ### Token

# %%
pprint([(X, X.ent_iob_, X.ent_type_) for X in doc])
# Out:
# [(Mark, 'B', 'PERSON'),
#  (playing, 'O', ''),
#  (in, 'O', ''),
#  (garden, 'O', ''),
#  (with, 'O', ''),
#  (his, 'O', ''),
#  (friend, 'O', ''),
#  (John, 'B', 'PERSON'),
#  (and, 'O', ''),
#  (searching, 'O', ''),
#  (for, 'O', ''),
#  (games, 'O', ''),
#  (on, 'O', ''),
#  (Google, 'B', 'ORG'),
#  (,, 'O', ''),
#  (on, 'O', ''),
#  (Monday, 'B', 'DATE'),
#  (at, 'O', ''),
#  (11, 'B', 'CARDINAL'),
#  (,, 'O', ''),
#  (suddenly, 'O', ''),
#  (they, 'O', ''),
#  (got, 'O', ''),
#  ($, 'O', ''),
#  (4, 'B', 'MONEY'),
#  (:), 'O', '')]

# %% [markdown]
# "B" means the token begins an entity, "I" means it is inside an entity, "O" means it is outside an entity, and "" means no entity tag is set

# %%
displacy.render(nlp(str(ex)), jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Mark
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  playing in garden with his friend
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     John
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and searching for games on
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  at
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     11
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# , suddenly they got $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  :)</div>

# %%
displacy.render(nlp(str(ex)), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="31dec0d3f95341cb83a9d4423e9e00c4-0" class="displacy" width="2810" height="557.0" direction="ltr" style="max-width: none; height: 557.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Mark</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">playing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">garden</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">his</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">friend</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">John</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">searching</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">games</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">Google,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">Monday</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">11,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">suddenly</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">they</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">got</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">$</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">4 :)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-31dec0d3f95341cb83a9d4423e9e00c4-0-0" stroke-width="2px" d="M70,422.0 C70,2.0 2450.0,2.0 2450.0,422.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-31dec0d3f95341cb83a9d4423e9e00c4-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">npadvmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,424.0 L62,412.0 78,412.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-31dec0d3f95341cb83a9d4423e9e00c4-0-1" stroke-width="2px" d="M70,422.0 C70,362.0 140.0,362.0 140.0,422.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-31dec0d3f95341cb83a9d4423e9e00c4-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M140.0,424.0 L148.0,412.0 132.0,412.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-31dec0d3f95341cb83a9d4423e9e00c4-0-2" stroke-width="2px" d="M190,422.0 C190,362.0 260.0,362.0 260.0,422.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-31dec0d3f95341cb83a9d4423e9e00c4-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M260.0,424.0 L268.0,412.0 252.0,412.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-31dec0d3f95341cb83a9d4423e9e00c4-0-3" stroke-width="2px" d="M310,422.0 C310,362.0 380.0,362.0 380.0,422.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; let

# %%
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(ex)) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('Mark', 'PROPN', 'Mark'),
#  ('playing', 'VERB', 'play'),
#  ('garden', 'NOUN', 'garden'),
#  ('friend', 'NOUN', 'friend'),
#  ('John', 'PROPN', 'John'),
#  ('searching', 'VERB', 'search'),
#  ('games', 'NOUN', 'game'),
#  ('Google', 'PROPN', 'Google'),
#  ('Monday', 'PROPN', 'Monday'),
#  ('11', 'NUM', '11'),
#  ('suddenly', 'ADV', 'suddenly'),
#  ('got', 'VERB', 'get'),
#  ('$', 'SYM', '$'),
#  ('4', 'NUM', '4')]

# %% [markdown]
# ### Named entity extraction

# %%
dict([(str(x), x.label_) for x in nlp(str(ex)).ents])
# Out:
# {'Mark': 'PERSON',
#  'John': 'PERSON',
#  'Google': 'ORG',
#  'Monday': 'DATE',
#  '11': 'CARDINAL',
#  '4': 'MONEY'}

# %%
print([(x, x.ent_iob_, x.ent_type_) for x in nlp(str(ex))])
# Out:
# [(Mark, 'B', 'PERSON'), (playing, 'O', ''), (in, 'O', ''), (garden, 'O', ''), (with, 'O', ''), (his, 'O', ''), (friend, 'O', ''), (John, 'B', 'PERSON'), (and, 'O', ''), (searching, 'O', ''), (for, 'O', ''), (games, 'O', ''), (on, 'O', ''), (Google, 'B', 'ORG'), (,, 'O', ''), (on, 'O', ''), (Monday, 'B', 'DATE'), (at, 'O', ''), (11, 'B', 'CARDINAL'), (,, 'O', ''), (suddenly, 'O', ''), (they, 'O', ''), (got, 'O', ''), ($, 'O', ''), (4, 'B', 'MONEY'), (:), 'O', '')]
